# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
#wichtige Befehle und ihre (prov) Reihenfolge

#platzhalter.find_all (Suche nach den einzelnen Einträgen und fasse sie zusammen)

#platzhalter.text (Umwandlung in Text)

# %%
#ZUSATZ!! wenn ich anonym bleiben will
import time
time.sleep(.002)

# %%
#r = request.get('LINK')

r = requests.get('https://kr-geschaefte.zug.ch/gast/geschaefte?commit=Filtern&geschaeft_filter%5Babgeschlossen_bis%5D=&geschaeft_filter%5Babgeschlossen_von%5D=&geschaeft_filter%5Barten_refs%5D%5B%5D=&geschaeft_filter%5Beingereicht_bis%5D=&geschaeft_filter%5Beingereicht_von%5D=&geschaeft_filter%5Bfrist_bis%5D=&geschaeft_filter%5Bhistorische_staende_refs%5D%5B%5D=&geschaeft_filter%5Bkommissionen_refs%5D%5B%5D=&geschaeft_filter%5Bstaende_refs%5D%5B%5D=&geschaeft_filter%5Bstatus_ids%5D%5B%5D=&geschaeft_filter%5Btitel%5D=&geschaeft_filter%5Bzustaendig_refs%5D%5B%5D=&page=1&utf8=✓')

soup = BeautifulSoup(r.text, 'html.parser') #das ist normalerweise der code, html.parser, so kann er html(o.a.) lesen

trlist = soup.find_all('tr') #das ist meine liste mit allen tr-tags von der seite, weiss ich dank f12!(entwickler fenster in chrome)!

trlist[2:] #ab diesem dritten Eintrag wird es interessant. drum, siehe unten, wandle ich das um von 2 bis unendlich.

trlist = trlist[2:]

trlist[0] #hier wieder der erste eintrag, hat sich also verschlankt seit der letzten [] eingabe
# Out:
# <tr>
# <td><a href="/gast/geschaefte/1998">3010</a></td>
# <td><a href="/gast/geschaefte/1998">Postulat von Ivo Egger, Stéphanie Vuichard, Hanni Schriber-Neiger und Andreas Lustenberger betreffend eines klimaneutralen, kantonalen Gebäudeparks des Kantons Zug</a></td>
# <td class="hidden-xs">Einreichung</td>
# <td class="hidden-xs">Baudirektion</td>
# <td class="hidden-xs">Postulat</td>
# <td class="hidden-xs">hängig</td>
# </tr>

# %%
# 'td' siehe oben in der klassifizierung, ist im ersten eintrag ein unterpunkt

trlist[0].find_all('td')
# Out:
# [<td><a href="/gast/geschaefte/1998">3010</a></td>,
#  <td><a href="/gast/geschaefte/1998">Postulat von Ivo Egger, Stéphanie Vuichard, Hanni Schriber-Neiger und Andreas Lustenberger betreffend eines klimaneutralen, kantonalen Gebäudeparks des Kantons Zug</a></td>,
#  <td class="hidden-xs">Einreichung</td>,
#  <td class="hidden-xs">Baudirektion</td>,
#  <td class="hidden-xs">Postulat</td>,
#  <td class="hidden-xs">hängig</td>]

# %%
trlist[0].find_all('td')[1].text
# Out:
# 'Postulat von Ivo Egger, Stéphanie Vuichard, Hanni Schriber-Neiger und Andreas Lustenberger betreffend eines klimaneutralen, kantonalen Gebäudeparks des Kantons Zug'

# %%
type(trlist[0])
# Out:
# bs4.element.Tag

# %%
#print ein eintrag:

temp = trlist[0].find_all('td')

for td_tag in temp:
        print(td_tag.text)
# Out:
# 487
# Genehmigung der Schlussabrechnung betreffend Restaurierung und Umbau der Athene sowie Erstellung eines Ergänzungsneubaus
# Datenmigration
#
# Verschiedenes
# abgeschlossen

# %%
temporary[0]
# Out:
# <td><a href="/gast/geschaefte/1998">3010</a></td>

# %%
trlist[0].find('a')['href'] #das ist der link auf die pdfs, die wir auch wollen.
# Out:
# '/gast/geschaefte/1998'

# %%
#hier wollen wir alles rausziehen und benamsen
#das ist der dummy für den loop nachher, so ziehen wir nur 1 element raus

td_list = trlist[0].find_all('td')
url = td_list[0].find('a')['href']
text = td_list[1].text
stand = td_list[2].text
zuständig = td_list[3].text
geschäftsart = td_list[4].text
status = td_list[5].text

mini_dict = {'url': url,
         'text': text,
         'stand': stand,
         'zuständig': zuständig, 
         'geschäftsart': geschäftsart,
         'status': status}

# %%
mini_dict
# Out:
# {'url': '/gast/geschaefte/1998',
#  'text': 'Postulat von Ivo Egger, Stéphanie Vuichard, Hanni Schriber-Neiger und Andreas Lustenberger betreffend eines klimaneutralen, kantonalen Gebäudeparks des Kantons Zug',
#  'stand': 'Einreichung',
#  'zuständig': 'Baudirektion',
#  'geschäftsart': 'Postulat',
#  'status': 'hängig'}

# %%
#so wird alles geloopt, siehe, dass im gegensatz zu oben trlist(in td_list) mit element ersetzt wird!!!!! Auch[0] weg
seite_eins = []

for element in trlist:
    td_list = element.find_all('td')
    url = td_list[0].find('a')['href']
    text = td_list[1].text
    stand = td_list[2].text
    zuständig = td_list[3].text
    geschäftsart = td_list[4].text
    status = td_list[5].text

    mini_dict = {'url': url,
         'text': text,
         'stand': stand,
         'zuständig': zuständig, 
         'geschäftsart': geschäftsart,
         'status': status}
    
    seite_eins.append(mini_dict)

# %%
pd.DataFrame(seite_eins)
# Out:
#                       url                                               text  \
# 0   /gast/geschaefte/1998  Postulat von Ivo Egger, Stéphanie Vuichard, Ha...
# 1   /gast/geschaefte/1997  Postulat von Stéphanie Vuichard, Mariann Hess ...
# 2   /gast/geschaefte/1996  Motion von Rainer Leemann und Michael Arnold b...
# 3   /gast/geschaefte/1995  Interpellation der SP-Fraktion betreffend Pest...
# 4   /gast/geschaefte/1994  Interpellation von Pirmin Andermatt und Heini ...
# 5   /gast/geschaefte/1993  Kantonsrats-Ersatzwahl in der Einwohnergemeind...
# 6   /gast/geschaefte/1992  Motion der CVP-Fraktion betreffend bedarfsgere...
# 7   /gast/geschaefte/1991  Postulat von Manuela Leemann, Benny Elsener un...
# 8   /gast/geschaefte/1990  Interpellation von Hans Baumgartner, Manuela K...
# 9   /gast/geschaefte/1989  Kantonsrats-Ersatzwahl in der Einwohnergemeind...
# 10  /gast/geschaefte/1988  Interpellation von Pirmin Andermatt, Zari Dzaf...
# ...

# %%
link_base = 'https://kr-geschaefte.zug.ch/gast/geschaefte?commit=Filtern&geschaeft_filter%5Babgeschlossen_bis%5D=&geschaeft_filter%5Babgeschlossen_von%5D=&geschaeft_filter%5Barten_refs%5D%5B%5D=&geschaeft_filter%5Beingereicht_bis%5D=&geschaeft_filter%5Beingereicht_von%5D=&geschaeft_filter%5Bfrist_bis%5D=&geschaeft_filter%5Bhistorische_staende_refs%5D%5B%5D=&geschaeft_filter%5Bkommissionen_refs%5D%5B%5D=&geschaeft_filter%5Bstaende_refs%5D%5B%5D=&geschaeft_filter%5Bstatus_ids%5D%5B%5D=&geschaeft_filter%5Btitel%5D=&geschaeft_filter%5Bzustaendig_refs%5D%5B%5D=&page='

alle_seiten = []

for seite in range(0,41):
    r = requests.get(link_base+str(seite))
    soup = BeautifulSoup(r.text, 'html.parser')
    
    trlist = soup.find_all('tr')[2:]
    
    for element in trlist:
        td_list = element.find_all('td')
        url = td_list[0].find('a')['href']
        text = td_list[1].text
        stand = td_list[2].text
        zuständig = td_list[3].text
        geschäftsart = td_list[4].text
        status = td_list[5].text

        mini_dict = {'url': url,
         'text': text,
         'stand': stand,
         'zuständig': zuständig, 
         'geschäftsart': geschäftsart,
         'status': status}
    
        alle_seiten.append(mini_dict)

# %%
pd.DataFrame(alle_seiten).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2013 entries, 0 to 2012
# Data columns (total 6 columns):
# url             2013 non-null object
# text            2013 non-null object
# stand           2013 non-null object
# zuständig       2013 non-null object
# geschäftsart    2013 non-null object
# status          2013 non-null object
# dtypes: object(6)
# memory usage: 94.5+ KB

# %%
allesei = pd.DataFrame(alle_seiten)

# %%
allesei.to_csv('Kantonsrat_alleseiten.csv')

# %%
#alles etwas vereinfachen mit einer funktion



link_base = 'https://kr-geschaefte.zug.ch/gast/geschaefte?commit=Filtern&geschaeft_filter%5Babgeschlossen_bis%5D=&geschaeft_filter%5Babgeschlossen_von%5D=&geschaeft_filter%5Barten_refs%5D%5B%5D=&geschaeft_filter%5Beingereicht_bis%5D=&geschaeft_filter%5Beingereicht_von%5D=&geschaeft_filter%5Bfrist_bis%5D=&geschaeft_filter%5Bhistorische_staende_refs%5D%5B%5D=&geschaeft_filter%5Bkommissionen_refs%5D%5B%5D=&geschaeft_filter%5Bstaende_refs%5D%5B%5D=&geschaeft_filter%5Bstatus_ids%5D%5B%5D=&geschaeft_filter%5Btitel%5D=&geschaeft_filter%5Bzustaendig_refs%5D%5B%5D=&page='

alle_seiten = []

for seite in range(0,41):
    r = requests.get(link_base+str(seite))
    soup = BeautifulSoup(r.text, 'html.parser')
    
    trlist = soup.find_all('tr')[2:]

#startet hier:

def minidict(listenelement):
    
    for element in listenelement:
        td_list = element.find_all('td')
        url = td_list[0].find('a')['href']
        text = td_list[1].text
        stand = td_list[2].text
        zuständig = td_list[3].text
        geschäftsart = td_list[4].text
        status = td_list[5].text

        mini_dict = {'url': url,
         'text': text,
         'stand': stand,
         'zuständig': zuständig, 
         'geschäftsart': geschäftsart,
         'status': status}
    
        return mini_dict

# %%
#neu!

alle_seiten = []

for seite in range(0,41):
    r = requests.get(link_base+str(seite))
    soup = BeautifulSoup(r.text, 'html.parser')
    
    trlist = soup.find_all('tr')[2:]
    
    minidict(trlist) #stimmt eventuell genau hier nicht, aber ist jetzt nicht ganz klar.

# %%
minidict(trlist)
# Out:
# {'url': '/gast/geschaefte/1317',
#  'text': 'Genehmigung der Schlussabrechnung betreffend Restaurierung und Umbau der Athene sowie Erstellung eines Ergänzungsneubaus',
#  'stand': 'Datenmigration',
#  'zuständig': '',
#  'geschäftsart': 'Verschiedenes',
#  'status': 'abgeschlossen'}

# %%
df = pd.DataFrame(alle_seiten)
df['url']
# Out:
# 0       /gast/geschaefte/1998
# 1       /gast/geschaefte/1997
# 2       /gast/geschaefte/1996
# 3       /gast/geschaefte/1995
# 4       /gast/geschaefte/1994
#                 ...
# 2008    /gast/geschaefte/1309
# 2009    /gast/geschaefte/1712
# 2010    /gast/geschaefte/1308
# 2011    /gast/geschaefte/1307
# 2012    /gast/geschaefte/1334
# Name: url, Length: 2013, dtype: object

# %%
url_liste_ganz = []

url_halb = ('https://kr-geschaefte.zug.ch')

for alles in df['url']:
    print(url_halb +alles)
# Out:
# https://kr-geschaefte.zug.ch/gast/geschaefte/1998
# https://kr-geschaefte.zug.ch/gast/geschaefte/1997
# https://kr-geschaefte.zug.ch/gast/geschaefte/1996
# https://kr-geschaefte.zug.ch/gast/geschaefte/1995
# https://kr-geschaefte.zug.ch/gast/geschaefte/1994
# https://kr-geschaefte.zug.ch/gast/geschaefte/1993
# https://kr-geschaefte.zug.ch/gast/geschaefte/1992
# https://kr-geschaefte.zug.ch/gast/geschaefte/1991
# https://kr-geschaefte.zug.ch/gast/geschaefte/1990
# https://kr-geschaefte.zug.ch/gast/geschaefte/1989
# https://kr-geschaefte.zug.ch/gast/geschaefte/1988
# https://kr-geschaefte.zug.ch/gast/geschaefte/1987
# https://kr-geschaefte.zug.ch/gast/geschaefte/1986
# https://kr-geschaefte.zug.ch/gast/geschaefte/1985
# https://kr-geschaefte.zug.ch/gast/geschaefte/1984
# https://kr-geschaefte.zug.ch/gast/geschaefte/1983
# https://kr-geschaefte.zug.ch/gast/geschaefte/1982
# https://kr-geschaefte.zug.ch/gast/geschaefte/1981
# https://kr-geschaefte.zug.ch/gast/geschaefte/1979
# ...
